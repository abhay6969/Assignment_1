# %%
"""Answer 1:
The Exception Class is Used when defining Custom Exception so that we can reuse the function for specific instructions written
inside the Exception class. Using the Exception class when creating custom exceptions ensures that our code is consistent, easy to 
understand, and conforms to best practices for exception handling """

# %%
"""Answer 2:
"""
import inspect
def print_exception(cls, indent=0):
    # Print the class name and its base classes
    print(' ' * indent + cls.__name__)
    for base_class in cls.__subclasses__():
        # Recursively print the base classes
        print_exception(base_class, indent + 3)
inspect.getclasstree(inspect.getmro(BaseException))

# Print the Python Exception Hierarchy
print_exception(BaseException)
# Out:
# BaseException
#    Exception
#       TypeError
#          FloatOperation
#          MultipartConversionError
#       StopAsyncIteration
#       StopIteration
#       ImportError
#          ModuleNotFoundError
#          ZipImportError
#       OSError
#          ConnectionError
#             BrokenPipeError
#             ConnectionAbortedError
#             ConnectionRefusedError
#             ConnectionResetError
#                RemoteDisconnected
#          BlockingIOError
#          ChildProcessError
#          FileExistsError
#          FileNotFoundError
#          IsADirectoryError
#          NotADirectoryError
#          InterruptedError
#             InterruptedSystemCall
#          PermissionError
#          ProcessLookupError
#          TimeoutError
#          UnsupportedOperation
#          itimer_error
#          herror
#          gaierror
#          SSLError
#             SSLCertVerificationError
#             SSLZeroReturnError
#             SSLWantWriteError
# ...

# %%
"""AirthematicError class is the class which is raised when an Airthematic error occurs in a python program.
ex:"""
def zero_division_error(a,b):
    print(a/b)
zero_division_error(5/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[8], line 5
#       3 def zero_division_error(a,b):
#       4     print(a/b)
# ----> 5 zero_division_error(5/0)
#
# ZeroDivisionError: division by zero

# %%
x = 1.0
y = 0.0
z = x / y
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 x = 1.0
#       2 y = 0.0
# ----> 3 z = x / y
#
# ZeroDivisionError: float division by zero

# %%
"""Answer 4:
LuckUpError class is raised when a error regarding an Index or Key is raised.
Ex:-"""
ar = [1,2,34,5,3]
print(ar[10])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 5
#       1 """Answer 4:
#       2 LuckUpError class is raised when a error regarding an Index or Key is raised.
#       3 Ex:-"""
#       4 ar = [1,2,34,5,3]
# ----> 5 print(ar[10])
#
# IndexError: list index out of range

# %%
"""Answer 5:
ImportError is raised when a specified module is either not present in the system as it hasn't been downloaded yet or the name of the
imported module is wrong.
Ex:-"""
import panda
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 5
#       1 """Answer 5:
#       2 ImportError is raised when a specified module is either not present in the system as it hasn't been downloaded yet or the name of the
#       3 imported module is wrong.
#       4 Ex:-"""
# ----> 5 import panda
#
# ModuleNotFoundError: No module named 'panda'

# %%
"""Answer 6:
Some Of the Best Practices for Exception Handlin are:
1. Use multiple except blocks for different exceptions: If you need to catch multiple types of exceptions, it's best to use
separate except blocks for each one.
2.Use the finally block for cleanup code: The finally block is a good place to put code that should always be executed, whether
an exception is raised or not.
3."""
